# %%
#Tắt cảnh báo
import warnings
warnings.filterwarnings('ignore')

#Thêm một số thư viện và lớp
import random
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score #Sự chính xác
from sklearn.metrics import precision_score #Độ chính xác
from sklearn.metrics import recall_score #Gọi lại
from sklearn.metrics import f1_score #F1
import matplotlib.pyplot as plt

#Tiêu đề
title = ['top-left1','top-left2','top-left3','top-left4','top-mid1','top-mid2','top-mid3','top-mid4','top-right1',
'top-right2','top-right3','top-right4','middle-left1','middle-left2','middle-left3','middle-left4','middle-mid1',' middle-mid2',
'middle-mid3','middle-mid4','middle-right1','middle-right2','middle-right3','middle-right4','bottom-left1','bottom-left2',
'bottom-left3','bottom-left4','bottom-mid1','bottom-mid2','bottom-mid3','bottom-mid4','bottom-right1','bottom-right2',
'bottom-right3','bottom-right4']

#Đọc dữ liệu Train - Test
data_train = pd.read_csv("data_statlog/sat.trn",encoding='utf-8',header=None,sep=' ')
data_test = pd.read_csv("data_statlog/sat.tst",encoding='utf-8',header=None,sep=' ')

#In dữ liệu
for i in range(0,len(title)):
    data_train.rename(columns={i:title[i]},inplace=True)
data_train.rename(columns={36:'Class'},inplace=True) #Thay đổi tiêu để cột thứ 36 và tham số inplace để chỉ định có hay không để thay đổi datafram hiện tại

data_train
# Out:
#       top-left1  top-left2  top-left3  top-left4  top-mid1  top-mid2  \
# 0            92        115        120         94        84       102
# 1            84        102        106         79        84       102
# 2            84        102        102         83        80       102
# 3            80        102        102         79        84        94
# 4            84         94        102         79        80        94
# ...         ...        ...        ...        ...       ...       ...
# 4430         56         64        108         96        64        71
# 4431         64         71        108         96        68        75
# 4432         68         75        108         96        71        87
# 4433         71         87        108         88        71        91
# 4434         71         91        100         81        76        95
#
#       top-mid3  top-mid4  top-right1  top-right2  ...  bottom-left4  \
# 0          106        79          84         102  ...           104
# 1          102        83          80         102  ...           100
# 2          102        79          84          94  ...            87
# 3          102        79          80          94  ...            79
# 4           98        76          80         102  ...            79
# ...        ...       ...         ...         ...  ...           ...
# 4430       108        96          68          75  ...            92
# 4431       108        96          71          87  ...            96
# 4432       108        88          71          91  ...            89
# 4433       100        81          76          95  ...            89
# 4434       108        88          80          95  ...            85
#
#       bottom-mid1  bottom-mid2  bottom-mid3  bottom-mid4  bottom-right1  \
# 0              88          121          128          100             84
# 1              84          107          113           87             84
# 2              84           99          104           79             84
# 3              84           99          104           79             84
# 4              84          103          104           79             79
# ...           ...          ...          ...          ...            ...
# 4430           66           83          108           96             66
# 4431           66           87          104           89             63
# 4432           63           87          104           89             70
# 4433           70          100          104           85             70
# 4434           70           91          104           85             63
#
#       bottom-right2  bottom-right3  bottom-right4  Class
# 0               107            113             87      3
# 1                99            104             79      3
# 2                99            104             79      3
# 3               103            104             79      3
# 4               107            109             87      3
# ...             ...            ...            ...    ...
# 4430             87            104             89      5
# 4431             87            104             89      5
# 4432            100            104             85      4
# 4433             91            104             85      4
# 4434             91            100             81      4
#
# [4435 rows x 37 columns]

# %%
'''     ---  1.KNN  ---   '''
from sklearn.neighbors import KNeighborsClassifier

#0. Các biến tham gia
lap = 10        #Cho biết là sẽ lặp 10 lần
tongKQF1_KNN = float(0)

#Vòng lặp
print('\tDự đoán nhãn bằng phương pháp K nearest neighbor')
for i in range(lap):

    #Dữ liệu bên tập dữ liệu huấn luyện
    x_train = data_train.values[:,:-1]     #Lấy tất cả các hàng và Các cột không phải cột lớp
    y_train = data_train.values[:,-1]      #Lấy tất cả các hàng của cột cuối

    #Dữ liệu bên tập dữ liệu kiểm tra
    x_test = data_test.values[:,:-1]       #Lấy tất cả các hàng và Các cột không phải cột lớp
    y_test = data_test.values[:,-1]        #Lấy tất cả các hàng của cột cuối

    langGieng = random.randint(100,150)
    print("=========================")
    print("Lặp lần thứ: {0} - K: {1}".format(i+1,langGieng))
    #1.Khởi tạo mô hình knn với sự random 100 - 150  phần tử liền kề
    model_KNN = KNeighborsClassifier(n_neighbors=langGieng)

    #2. Huấn luyện mô hình
    model_KNN.fit(x_train,y_train)

    #3. Dự đoán nhãn cho mô hình
    y_pred = model_KNN.predict(x_test)

    #4. Đánh giá 
    f1 = f1_score(y_test,y_pred,average="macro")   #Gồm Tập nhãn thực tế, tập nhãn dữ đoán và Tính F1 score theo từng nhãn và sau đó lấy trung bình cộng của các F1 score này. Phương pháp này là phương pháp mặc định.
    print(f'Độ chính xác: {accuracy_score(y_test,y_pred)*100:.2f}%')
    print(f'F1-score: {f1*100:.2f}%')

    #5.Lưu vào mảng
    tongKQF1_KNN += f1

#Trung bình cộng của F1 khi 10 lần lặp
print(f"Trung Bình cộng của F1 khi thực hiện {lap} lần lặp bằng phương pháp KNN: {(tongKQF1_KNN/lap)*100:.2f}%")
# Out:
# 	Dự đoán nhãn bằng phương pháp K nearest neighbor
# =========================
# Lặp lần thứ: 1 - K: 150
# Độ chính xác: 83.70%
# F1-score: 80.79%
# =========================
# Lặp lần thứ: 2 - K: 102
# Độ chính xác: 84.80%
# F1-score: 82.22%
# =========================
# Lặp lần thứ: 3 - K: 122
# Độ chính xác: 84.20%
# F1-score: 81.54%
# =========================
# Lặp lần thứ: 4 - K: 146
# Độ chính xác: 83.65%
# F1-score: 80.74%
# =========================
# Lặp lần thứ: 5 - K: 148
# Độ chính xác: 83.70%
# F1-score: 80.79%
# =========================
# Lặp lần thứ: 6 - K: 124
# Độ chính xác: 84.25%
# F1-score: 81.58%
# =========================
# Lặp lần thứ: 7 - K: 109
# Độ chính xác: 84.55%
# F1-score: 81.94%
# =========================
# Lặp lần thứ: 8 - K: 149
# Độ chính xác: 83.85%
# F1-score: 80.95%
# =========================
# Lặp lần thứ: 9 - K: 112
# Độ chính xác: 84.55%
# F1-score: 81.94%
# =========================
# Lặp lần thứ: 10 - K: 126
# Độ chính xác: 84.20%
# F1-score: 81.47%
# Trung Bình cộng của F1 khi thực hiện 10 lần lặp bằng phương pháp KNN: 81.40%

# %%
''' 3. Cây quyết định bằng gini'''

from sklearn.tree import DecisionTreeClassifier

#Các biến tham gia
TongKQ_DTC = float(0)
SoLuongNgauNhien = random.randint(100,150)

#Vòng lặp
print('\tDự đoán nhãn bằng phương pháp cây quyết định')
for i in range(lap):

    #Dữ liệu bên tập dữ liệu huấn luyện
    x_train = data_train.values[:,:-1]     #Lấy tất cả các hàng và Các cột không phải cột lớp
    y_train = data_train.values[:,-1]      #Lấy tất cả các hàng của cột cuối

    #Dữ liệu bên tập dữ liệu kiểm tra
    x_test = data_test.values[:,:-1]       #Lấy tất cả các hàng và Các cột không phải cột lớp
    y_test = data_test.values[:,-1]        #Lấy tất cả các hàng của cột cuối

    print('==========================')
    print(f'Lần lặp thứ {i}')
    #1.Khởi tạo mô hình
    indexGiNi = DecisionTreeClassifier(criterion="gini",max_depth=5)

    #2.Huấn luyện mô hình
    indexGiNi.fit(x_train,y_train)

    #3.Dự đoán nhãn cho tập dữ liệu kiểm tra
    y_predict = indexGiNi.predict(x_test)

    #4. Đánh giá
    F1 = f1_score(y_test,y_predict, average="macro")    #Gồm Tập nhãn thực tế, tập nhãn dữ đoán và Tính F1 score theo từng nhãn và sau đó lấy trung bình cộng của các F1 score này. Phương pháp này là phương pháp mặc định.
    Recall = recall_score(y_test,y_predict,average="macro")
    Accuracy = accuracy_score(y_test,y_predict)
    Precision = precision_score(y_test,y_predict,average="macro")
    print(f'F1_score: {F1*100:.3f}%')
    print(f'Độ chính xác: {Precision*100:.3f}%')
    print(f'Sự chính xác: {Accuracy*100:.3f}%')
    print(f'Recall: {Recall*100:.3f}%')

    #Tổng kết quả F1 sau mỗi lần lặp
    TongKQ_DTC+=F1

#Tính trung bình cộng của F1 sau 5 lần lặp
print(f"Trung Bình cộng của F1 khi thực hiện {lap} lần lặp bằng phương pháp Cây quyết định: {(TongKQ_DTC/lap)*100:.3f}%")
# Out:
# 	Dự đoán nhãn bằng phương pháp cây quyết định
# ==========================
# Lần lặp thứ 0
# F1_score: 76.482%
# Độ chính xác: 77.566%
# Sự chính xác: 80.700%
# Recall: 76.011%
# ==========================
# Lần lặp thứ 1
# F1_score: 76.513%
# Độ chính xác: 77.583%
# Sự chính xác: 80.750%
# Recall: 76.053%
# ==========================
# Lần lặp thứ 2
# F1_score: 76.513%
# Độ chính xác: 77.583%
# Sự chính xác: 80.750%
# Recall: 76.053%
# ==========================
# Lần lặp thứ 3
# F1_score: 76.397%
# Độ chính xác: 77.474%
# Sự chính xác: 80.650%
# Recall: 75.941%
# ==========================
# Lần lặp thứ 4
# F1_score: 76.513%
# Độ chính xác: 77.583%
# Sự chính xác: 80.750%
# Recall: 76.053%
# ==========================
# Lần lặp thứ 5
# F1_score: 76.513%
# Độ chính xác: 77.583%
# Sự chính xác: 80.750%
# Recall: 76.053%
# ==========================
# Lần lặp thứ 6
# F1_score: 76.513%
# Độ chính xác: 77.583%
# Sự chính xác: 80.750%
# Recall: 76.053%
# ==========================
# Lần lặp thứ 7
# F1_score: 76.521%
# Độ chính xác: 77.610%
# Sự chính xác: 80.750%
# Recall: 76.047%
# ==========================
# Lần lặp thứ 8
# F1_score: 76.429%
# Độ chính xác: 77.491%
# Sự chính xác: 80.700%
# Recall: 75.983%
# ==========================
# Lần lặp thứ 9
# F1_score: 76.513%
# Độ chính xác: 77.583%
# Sự chính xác: 80.750%
# Recall: 76.053%
# Trung Bình cộng của F1 khi thực hiện 10 lần lặp bằng phương pháp Cây quyết định: 76.491%

# %%
'''4. Cây quyết định. '''
from sklearn.ensemble import RandomForestClassifier

'''
    - Giải thích về Lớp RandomForestClassifier() của thư viện Scikit-Learn là một mô hình phân loại 
    dựa trên rừng cây quyết định ngẫu nhiên. Mô hình này hoạt động bằng cách xây dựng một tập hợp các 
    cây quyết định ngẫu nhiên, sau đó sử dụng tập hợp này để dự đoán lớp của các mẫu mới.
    -Lớp RandomForestClassifier() có các thuộc tính sau:

        + n_estimators: Số lượng cây quyết định trong rừng.
        + max_depth: Độ sâu tối đa của mỗi cây quyết định.
        + min_samples_split: Số lượng mẫu tối thiểu cần thiết để chia một nút.
        + min_samples_leaf: Số lượng mẫu tối thiểu cần thiết để tạo một nút lá.
        + max_features: Số lượng thuộc tính tối đa được sử dụng để chia một nút.
        + bootstrap: Phương pháp lấy mẫu dữ liệu để xây dựng các cây quyết định.
        + criterion: Tiêu chí được sử dụng để phân chia các nút trong cây quyết định.
        + class_weight: Cân bằng trọng số của các lớp trong tập dữ liệu.
'''
TongKQF1_RF = float(0)
for i in range(lap):

    #Dữ liệu bên tập dữ liệu huấn luyện
    x_train = data_train.values[:,:-1]     #Lấy tất cả các hàng và Các cột không phải cột lớp
    y_train = data_train.values[:,-1]      #Lấy tất cả các hàng của cột cuối

    #Dữ liệu bên tập dữ liệu kiểm tra
    x_test = data_test.values[:,:-1]       #Lấy tất cả các hàng và Các cột không phải cột lớp
    y_test = data_test.values[:,-1]        #Lấy tất cả các hàng của cột cuối
    #---------------------------------------------
    print(f"Lần lặp thứ {i}:")
    clf = RandomForestClassifier(n_estimators=random.randint(100,150),max_depth=5)

    #1.Huấn luyện
    clf.fit(x_train,y_train)

    #2.Dự báo
    y_pred = clf.predict(x_test)

    #3. Đánh giá
    F1 = f1_score(y_test,y_pred, average='macro')
    Accuracy = accuracy_score(y_test,y_pred)
    Recall = recall_score(y_test,y_pred, average='macro')
    Precision = precision_score(y_test,y_pred, average='macro')
    TongKQF1_RF +=F1

    #4. In kết quả
    print(f'F1: {F1*100:.3f}%')
    print(f'Độ chính xác: {Accuracy*100:.3f}%')
    print(f'Recall: {Recall*100:.3f}%')
    print(f'Sự chính xác: {Precision*100:.3f}%')
    print('======================')

print(f"Trung Bình cộng của F1 khi thực hiện {lap} lần lặp bằng phương pháp Rừng ngẫu nhiên: {(TongKQF1_RF/lap)*100:.3f}%")
# Out:
# Lần lặp thứ 0:
# F1: 82.581%
# Độ chính xác: 85.650%
# Recall: 81.238%
# Sự chính xác: 86.165%
# ======================
# Lần lặp thứ 1:
# F1: 83.019%
# Độ chính xác: 86.000%
# Recall: 81.728%
# Sự chính xác: 86.427%
# ======================
# Lần lặp thứ 2:
# F1: 82.831%
# Độ chính xác: 85.850%
# Recall: 81.575%
# Sự chính xác: 86.021%
# ======================
# Lần lặp thứ 3:
# F1: 81.785%
# Độ chính xác: 84.850%
# Recall: 80.535%
# Sự chính xác: 85.013%
# ======================
# Lần lặp thứ 4:
# F1: 82.613%
# Độ chính xác: 85.500%
# Recall: 81.362%
# Sự chính xác: 85.766%
# ======================
# Lần lặp thứ 5:
# F1: 82.736%
# Độ chính xác: 85.750%
# Recall: 81.471%
# Sự chính xác: 86.114%
# ======================
# Lần lặp thứ 6:
# F1: 82.698%
# Độ chính xác: 85.700%
# Recall: 81.417%
# Sự chính xác: 85.932%
# ======================
# Lần lặp thứ 7:
# F1: 83.088%
# Độ chính xác: 86.000%
# Recall: 81.867%
# Sự chính xác: 86.227%
# ======================
# Lần lặp thứ 8:
# F1: 82.567%
# Độ chính xác: 85.600%
# Recall: 81.289%
# Sự chính xác: 85.760%
# ======================
# Lần lặp thứ 9:
# F1: 82.855%
# Độ chính xác: 85.900%
# Recall: 81.529%
# Sự chính xác: 86.364%
# ======================
# Trung Bình cộng của F1 khi thực hiện 10 lần lặp bằng phương pháp Rừng ngẫu nhiên: 82.677%

# %%
#Vẽ biểu đồ so sánh độ chính xác F1 của 3 giải thuật trên
BieuDoSoSanh = plt
GiaiThuat = [f'KNN\n{(tongKQF1_KNN/lap)*100:.3f}%' ,
             f'Decision tree\n{(TongKQ_DTC/lap)*100:.3f}%',
             f'Random forests\n{(TongKQF1_RF/lap)*100:.3f}%']

KQ = [(tongKQF1_KNN/lap)*100,(TongKQ_DTC/lap)*100,(TongKQF1_RF/lap)*100]
BieuDoSoSanh.ylabel('F1')
BieuDoSoSanh.bar(GiaiThuat,KQ,color='blue')
BieuDoSoSanh.ylim(0,100)
BieuDoSoSanh.show()
